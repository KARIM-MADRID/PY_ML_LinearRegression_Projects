# %% [markdown]
# ### DETECT OUTLIER USING PERCENTILE % Z SCORE method

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\ibast\Downloads\house price prediction.zip")

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %% [markdown]
# #### Explore samples that are above 99.90% percentile and below 1% percentile rank

# %%
min_thresold, max_thresold = df.price.quantile([0.001, 0.999])
min_thresold, max_thresold
# Out:
# (11.159500000000001, 2000.0)

# %%
df[df.price < min_thresold]
# Out:
#                   area_type          availability            location  \
# 171    Super built-up  Area         Ready To Move            Attibele
# 942          Built-up  Area         Ready To Move            Attibele
# 1471         Built-up  Area                18-Mar             Kengeri
# 2437         Built-up  Area         Ready To Move            Attibele
# 4113   Super built-up  Area                18-Jan          BTM Layout
# 5410   Super built-up  Area         Ready To Move            Attibele
# 7482   Super built-up  Area         Ready To Move                Alur
# 8594         Built-up  Area         Ready To Move          Chandapura
# 8653             Plot  Area         Ready To Move       Doddaballapur
# 10526  Super built-up  Area         Ready To Move  Yelahanka New Town
# 11091        Built-up  Area         Ready To Move            Attibele
# 11569            Plot  Area  Immediate Possession          Hosur Road
# ...

# %%
df[df.price > max_thresold]
# Out:
#                   area_type   availability               location        size  \
# 408    Super built-up  Area         19-Jan           Rajaji Nagar       7 BHK
# 605    Super built-up  Area         19-Jan           Malleshwaram       7 BHK
# 2623             Plot  Area         18-Jul       Dodsworth Layout   4 Bedroom
# 3180   Super built-up  Area  Ready To Move        Shanthala Nagar       5 BHK
# 4162         Built-up  Area  Ready To Move                 Yemlur   4 Bedroom
# 6421             Plot  Area         18-Sep           Bommenahalli   4 Bedroom
# 10304            Plot  Area  Ready To Move    5th Block Jayanagar   4 Bedroom
# 11080  Super built-up  Area         18-Jan            Ashok Nagar       4 BHK
# 11763            Plot  Area  Ready To Move        Sadashiva Nagar   5 Bedroom
# 12443            Plot  Area  Ready To Move         Dollars Colony   4 Bedroom
# 13067            Plot  Area  Ready To Move         Defence Colony  10 Bedroom
# ...

# %% [markdown]
# ### REMOVE OUTLIERS

# %%
df2 = df[(df.price<max_thresold) & (df.price>min_thresold)]
df2.shape
# Out:
# (13291, 9)

# %%
df2.describe()
# Out:
#                bath       balcony         price
# count  13219.000000  12688.000000  13291.000000
# mean       2.690673      1.584253    110.010361
# std        1.335757      0.817169    125.434347
# min        1.000000      0.000000     11.500000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   1950.000000

# %% [markdown]
# #### Detecting outlier using Z score
# Using Z score
# Formula for Z score = (Observation — Mean)/Standard Deviation
#
# z = (X — μ) / σ

# %%
import numpy as np

# %%
outliers=[]
def detect_outliers(data):
    
    threshold=3
    mean = np.mean(data)
    std =np.std(data)
    
    
    for i in df:
        z_score= (i - mean)/std 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %%
outlier_pt=detect_outliers(df)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_80252/423297114.py in <module>
# ----> 1 outlier_pt=detect_outliers(df)
#
# ~\AppData\Local\Temp/ipykernel_80252/2268503503.py in detect_outliers(data)
#       8
#       9     for i in df:
# ---> 10         z_score= (i - mean)/std
#      11         if np.abs(z_score) > threshold:
#      12             outliers.append(y)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __rsub__(self, other)
#     102     @unpack_zerodim_and_defer("__rsub__")
#     103     def __rsub__(self, other):
# --> 104         return self._arith_method(other, roperator.rsub)
#     105
# ...

# %%
outlier_pt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_80252/450534106.py in <module>
# ----> 1 outlier_pt
#
# NameError: name 'outlier_pt' is not defined
